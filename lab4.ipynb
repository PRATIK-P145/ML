# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 202          203         0       3
# 811          812         0       3
# 291          292         1       1
# 564          565         0       3
# 569          570         1       3
# 622          623         1       3
# 230          231         1       1
# 570          571         1       2
# 277          278         0       2
# 764          765         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 202                    Johanson, Mr. Jakob Alfred    male  34.0      0      0
# 811                             Lester, Mr. James    male  39.0      0      0
# 291       Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1      0
# 564                Meanwell, Miss. (Marion Ogden)  female   NaN      0      0
# 569                             Jonsson, Mr. Carl    male  32.0      0      0
# 622                              Nakid, Mr. Sahid    male  20.0      1      1
# 230  Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1      0
# 570                            Harris, Mr. George    male  62.0      0      0
# 277                   Parkes, Mr. Francis "Frank"    male   NaN      0      0
# 764                        Eklund, Mr. Hans Linus    male  16.0      0      0
#
#                 Ticket     Fare Cabin Embarked
# 202            3101264   6.4958   NaN        S
# 811          A/4 48871  24.1500   NaN        S
# 291              11967  91.0792   B49        C
# 564  SOTON/O.Q. 392087   8.0500   NaN        S
# 569             350417   7.8542   NaN        S
# 622               2653  15.7417   NaN        C
# 230              36973  83.4750   C83        S
# 570        S.W./PP 752  10.5000   NaN        S
# 277             239853   0.0000   NaN        S
# 764             347074   7.7750   NaN        S

# %%
df.drop(df[['PassengerId','Name','Ticket','Cabin']],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en=LabelEncoder()

# %%
df['Sex']=pd.DataFrame(en.fit_transform(df['Sex']))

# %%
df['Embarked']=pd.DataFrame(en.fit_transform(df['Embarked']))

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import cross_val_predict, StratifiedKFold, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,ConfusionMatrixDisplay

# %%
X=df.drop("Survived",axis=1)
y=df.Survived

# %%
models = {
    "Naive Bayes": GaussianNB(),
    "Logistic Regression": LogisticRegression(max_iter=1000)
}
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
for name, model in models.items():
    y_pred = cross_val_predict(model, X, y, cv=cv)
    print("Classification Report:\n", classification_report(y, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       424
#            1       0.75      0.70      0.72       290
#
#     accuracy                           0.78       714
#    macro avg       0.77      0.77      0.77       714
# weighted avg       0.78      0.78      0.78       714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       424
#            1       0.78      0.71      0.75       290
#
#     accuracy                           0.80       714
#    macro avg       0.80      0.79      0.79       714
# weighted avg       0.80      0.80      0.80       714
